# %%
# %run covid-19-data.ipynb

import pandas as pd
import numpy as np

confirmed_global='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
covid19_confirmed=pd.read_csv(confirmed_global)

deaths_global='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
covid19_deaths=pd.read_csv(deaths_global)

recovered_global='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
covid19_recovered=pd.read_csv(recovered_global)

confirmed_latest = covid19_confirmed.T.index.values[-1]
deaths_latest = covid19_deaths.T.index.values[-1]
recovered_latest = covid19_recovered.T.index.values[-1]

# %%
df=covid19_confirmed.groupby('Country/Region').sum().reset_index()
df=df.sort_values(confirmed_latest,ascending=False).head(30).drop(['Lat', 'Long'],axis=1).set_index("Country/Region").T
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'8 COVID-19 Time series Confirmed as of {confirmed_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.rc('legend', fontsize=16)
plt.tick_params(labelsize=16)
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.legend(loc=2)
plt.show()

# %%
df=covid19_deaths.groupby('Country/Region').sum().reset_index()
df=df.sort_values(deaths_latest,ascending=False).head(30).drop(['Lat', 'Long'],axis=1).set_index("Country/Region").T
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'COVID-19 Time series Death as of {deaths_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.rc('legend', fontsize=16)
plt.tick_params(labelsize=16)
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.legend(loc=2)
plt.show()

# %%
df=covid19_recovered.groupby('Country/Region').sum().reset_index()
df=df.sort_values(recovered_latest,ascending=False).head(30).drop(['Lat', 'Long'],axis=1).set_index("Country/Region").T
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'COVID-19 Time series Death as of {recovered_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.rc('legend', fontsize=16)
plt.tick_params(labelsize=16)
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.legend(loc=2)
plt.show()

# %%
# Total Confirmed by date
from matplotlib.ticker import ScalarFormatter

covid19_confirmed.loc["Total"] = covid19_confirmed.sum()
df=covid19_confirmed.iloc[-1,4:]
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'COVID-19 Time series Global confirmed as of {confirmed_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.tick_params(labelsize=16)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="plain",  axis="y")
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.show()

# %%
# Total deaths by date
from matplotlib.ticker import ScalarFormatter

covid19_deaths.loc["Total"] = covid19_deaths.sum()
df=covid19_deaths.iloc[-1,4:]
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'COVID-19 Time series total deaths as of {deaths_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.tick_params(labelsize=16)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="plain",  axis="y",scilimits=(0,0))
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.show()

# %%
# Total recovered by date
from matplotlib.ticker import ScalarFormatter

covid19_recovered.loc["Total"] = covid19_recovered.sum()
df=covid19_recovered.iloc[-1,4:]
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
df.plot(ax=ax,figsize=(20,20))
ax.set_title(f'COVID-19 Time series total recovered as of {recovered_latest}',fontsize= 30)
plt.xlabel('Date',fontsize= 20)
plt.ylabel('Number',fontsize= 20)
plt.tick_params(labelsize=16)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="plain",  axis="y",scilimits=(0,0))
fig.autofmt_xdate() # mke space for and rotate the x-axis tick labels
plt.show()
